# %%
from ray.tune.schedulers import PopulationBasedTraining
from ray import tune, air
from ray.rllib.algorithms.ppo import PPO, PPOConfig
from ray.rllib.policy.policy import PolicySpec
from ray.rllib.algorithms.ppo import PPO, PPOConfig
# TODO relative import
from envs import MultiAgentBuildingEnv, MonoAgentBuildingEnv
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731752154.772027 1726881 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731752154.775497 1726881 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
pbt = PopulationBasedTraining(
    time_attr="training_iteration",
    perturbation_interval=4,
    resample_probability=0.25,
    hyperparam_mutations={
        "lr": tune.uniform(1e-5, 0.1),
        "batch_mode": ["complete_episodes"],
        #"train_batch_size": [4000],
        "sgd_minibatch_size": [32, 64, 128, 256, 512],
        "num_sgd_iter": [10, 20, 30],
        "clip_param": tune.uniform(0.1, 0.3),
    },
)

tuner = tune.Tuner(
    PPO,
    param_space=(
        MultiAgentBuildingEnv.get_algo_config(
            PPOConfig()
            .rollouts(
                num_rollout_workers=2, 
                #rollout_fragment_length='auto',
                rollout_fragment_length=200,
            )
            .resources(num_gpus=0.25)
        )
    ),
    tune_config=tune.TuneConfig(
        #reuse_actors=True,
        scheduler=pbt,
        num_samples=2,
        metric="env_runners/episode_reward_mean",
        mode="max",
    ),
    run_config=air.RunConfig(
        stop={"training_iteration": 200},
        checkpoint_config=air.CheckpointConfig(
            checkpoint_at_end=True
        ),
        verbose=2,
    )
)
results = tuner.fit()
# Out:
# 2024-11-16 10:16:00,952	WARNING deprecation.py:50 -- DeprecationWarning: `rollouts` has been deprecated. Use `AlgorithmConfig.env_runners(..)` instead. This will raise an error in the future!
# 2024-11-16 10:16:00,953	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_rollout_workers)` has been deprecated. Use `AlgorithmConfig.env_runners(num_env_runners)` instead. This will raise an error in the future!
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/_private/node.py:1362: ResourceWarning: unclosed file <_io.TextIOWrapper name='/tmp/ray/session_2024-11-16_10-16-00_972091_1726881/logs/gcs_server.out' mode='a' encoding='utf-8'>
#   self.start_gcs_server()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/_private/node.py:1362: ResourceWarning: unclosed file <_io.TextIOWrapper name='/tmp/ray/session_2024-11-16_10-16-00_972091_1726881/logs/gcs_server.err' mode='a' encoding='utf-8'>
#   self.start_gcs_server()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/_private/node.py:1367: ResourceWarning: unclosed file <_io.TextIOWrapper name='/tmp/ray/session_2024-11-16_10-16-00_972091_1726881/logs/monitor.out' mode='a' encoding='utf-8'>
#   self.start_monitor()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/_private/node.py:1367: ResourceWarning: unclosed file <_io.TextIOWrapper name='/tmp/ray/session_2024-11-16_10-16-00_972091_1726881/logs/monitor.err' mode='a' encoding='utf-8'>
#   self.start_monitor()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/_private/node.py:1378: ResourceWarning: unclosed file <_io.TextIOWrapper name='/tmp/ray/session_2024-11-16_10-16-00_972091_1726881/logs/dashboard.err' mode='a' encoding='utf-8'>
#   self.start_api_server(
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/_private/node.py:1420: ResourceWarning: unclosed file <_io.TextIOWrapper name='/tmp/ray/session_2024-11-16_10-16-00_972091_1726881/logs/raylet.out' mode='a' encoding='utf-8'>
#   self.start_raylet(plasma_directory, object_store_memory)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/_private/node.py:1420: ResourceWarning: unclosed file <_io.TextIOWrapper name='/tmp/ray/session_2024-11-16_10-16-00_972091_1726881/logs/raylet.err' mode='a' encoding='utf-8'>
#   self.start_raylet(plasma_directory, object_store_memory)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/_private/node.py:1422: ResourceWarning: unclosed file <_io.TextIOWrapper name='/tmp/ray/session_2024-11-16_10-16-00_972091_1726881/logs/log_monitor.err' mode='a' encoding='utf-8'>
#   self.start_log_monitor()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# 2024-11-16 10:16:01,575	INFO worker.py:1786 -- Started a local Ray instance.
# 2024-11-16 10:16:02,101	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# 2024-11-16 10:16:02,103	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-11-16 10:18:17</td></tr>
# <tr><td>Running for: </td><td>00:02:15.52        </td></tr>
# <tr><td>Memory:      </td><td>20.2/31.2 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       PopulationBasedTraining: 0 checkpoints, 0 perturbs<br>Logical resource usage: 6.0/24 CPUs, 0.5/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                           </th><th>status  </th><th>loc                    </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_MultiAgentBuildingEnv_c81eb_00000</td><td>RUNNING </td><td>192.168.200.249:1728512</td><td style="text-align: right;">     1</td><td style="text-align: right;">         75.242 </td><td style="text-align: right;">4000</td><td style="text-align: right;">                    2</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# <tr><td>PPO_MultiAgentBuildingEnv_c81eb_00001</td><td>RUNNING </td><td>192.168.200.249:1728516</td><td style="text-align: right;">     1</td><td style="text-align: right;">         77.3583</td><td style="text-align: right;">4000</td><td style="text-align: right;">                    2</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (pid=1728512) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=1728512) E0000 00:00:1731752162.973861 1728512 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=1728512) E0000 00:00:1731752162.977459 1728512 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=1728699) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=1728699) E0000 00:00:1731752169.484674 1728699 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 2x across cluster]
# (pid=1728516) E0000 00:00:1731752162.976821 1728516 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=1728698) E0000 00:00:1731752169.480040 1728698 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#   0%|          | 0/100 [00:00<?, ?it/s]
# (pid=1728700) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 3x across cluster]
# (pid=1728700) E0000 00:00:1731752169.476851 1728700 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 3x across cluster]
# (pid=1728701) E0000 00:00:1731752169.487994 1728701 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered [repeated 3x across cluster]
#   0%|          | 0/100 [00:00<?, ?it/s, EnergyPlus, Version 23.2.0-7636e6b3e9, YMD=2024.11.16 10:16]
#   0%|          | 0.0/100 [00:00<?, ?it/s, EnergyPlus, Version 23.2.0-7636e6b3e9, YMD=2024.11.16 10:16]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Determining Shadowing Combinations]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Proceeding with Initializing Solar Calculations]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Setting up Surface Reporting Variables]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Setting up Surface Reporting Variables]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Gathering Information for Predefined Reporting]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Warming up]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Warming up]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Warming up]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Warming up]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Warming up]
# (PPO pid=1728512) Install gputil for GPU system monitoring.
#   0%|          | 0.0/100 [00:00<?, ?it/s, Warming up]
#   0%|          | 0.0/100 [00:01<?, ?it/s, ...for Sizing Period: #1 SUMMER DESIGN DAY IN SITE (01-01:31-12) JUL]/home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='0FGROUNDFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='0FGROUNDFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='0FGROUNDFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
# (RolloutWorker pid=1728699) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728699)   _warnings_.warn(
#   0%|          | 0.0/100 [00:01<?, ?it/s, ...for Sizing Period: #1 SUMMER DESIGN DAY IN SITE (01-01:31-12) JUL]/home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728701) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Schedule Value', key='Office_OpenOff_Occ')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   0%|          | 0.0/100 [00:01<?, ?it/s, ...for Sizing Period: #1 SUMMER DESIGN DAY IN SITE (01-01:31-12) JUL]/home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Schedule Value', key='Office_OpenOff_Occ')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   0%|          | 0.0/100 [00:01<?, ?it/s, ...for Sizing Period: #1 SUMMER DESIGN DAY IN SITE (01-01:31-12) JUL]/home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up]
#   0%|          | 0.0/100 [00:01<?, ?it/s, ...for Sizing Period: #2 WINTER DESIGN DAY IN SITE (01-01:31-12)]
#   0%|          | 0.0/100 [00:01<?, ?it/s, ...for Sizing Period: #2 WINTER DESIGN DAY IN SITE (01-01:31-12)]
#   0%|          | 0.0/100 [00:01<?, ?it/s, ...for Sizing Period: #2 WINTER DESIGN DAY IN SITE (01-01:31-12)]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up {1}]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Reporting Surfaces]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up {2}]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up {2}]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up {3}]
#   3%|▎         | 3.0/100 [00:01<00:50,  1.91it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]
#   3%|▎         | 3.0/100 [00:02<00:55,  1.76it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]/home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Schedule Value', key='Office_OpenOff_Occ')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   6%|▌         | 6.0/100 [00:02<00:23,  3.95it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]
#   0%|          | 0/100 [00:00<?, ?it/s] [repeated 3x across cluster]
#   0%|          | 0/100 [00:00<?, ?it/s, EnergyPlus, Version 23.2.0-7636e6b3e9, YMD=2024.11.16 10:16] [repeated 3x across cluster]
#   0%|          | 0.0/100 [00:00<?, ?it/s, EnergyPlus, Version 23.2.0-7636e6b3e9, YMD=2024.11.16 10:16]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up]                                                           [repeated 9x across cluster]
#  62%|██████▏   | 62.0/100 [00:05<00:02, 15.80it/s, Updating Shadowing Calculations, Start Date=07/21/2002]
# (PPO pid=1728516) Install gputil for GPU system monitoring.
#   0%|          | 0.0/100 [00:00<?, ?it/s, Warming up] [repeated 6x across cluster]
#  65%|██████▌   | 65.0/100 [00:05<00:02, 15.64it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)]
# (RolloutWorker pid=1728699)   _warnings_.warn( [repeated 20x across cluster]
# (RolloutWorker pid=1728700) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable [repeated 7x across cluster]
# (RolloutWorker pid=1728701) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable [repeated 7x across cluster]
# (RolloutWorker pid=1728700) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Schedule Value', key='Office_OpenOff_Occ')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#  68%|██████▊   | 68.0/100 [00:06<00:02, 15.67it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up] [repeated 3x across cluster]
#   0%|          | 0.0/100 [00:01<?, ?it/s, ...for Sizing Period: #2 WINTER DESIGN DAY IN SITE (01-01:31-12)]
#  71%|███████   | 71.0/100 [00:06<00:01, 15.67it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up {1}]                          [repeated 2x across cluster]
#  74%|███████▍  | 74.0/100 [00:06<00:01, 15.68it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)]
#   0%|          | 0.0/100 [00:02<?, ?it/s, Warming up {6}] [repeated 7x across cluster]
#   0%|          | 0.0/100 [00:01<?, ?it/s, Warming up {5}] [repeated 3x across cluster]
#   3%|▎         | 3.0/100 [00:02<00:52,  1.84it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)] [repeated 2x across cluster]
#  59%|█████▉    | 59.0/100 [00:07<00:03, 11.00it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]              [repeated 75x across cluster]
#  94%|█████████▍| 94.0/100 [00:07<00:00, 15.44it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)]
# 100%|██████████| 100.0/100 [00:08<00:00, 19.98it/s, EnergyPlus, Version 23.2.0-7636e6b3e9, YMD=2024.11.16 10:16]
#   0%|          | 0.0/100 [00:08<00:05, 19.98it/s, Gathering Information for Predefined Reporting]
#   0%|          | 0.0/100 [00:08<00:05, 19.98it/s, Warming up]
#   0%|          | 0.0/100 [00:08<00:05, 19.98it/s, Warming up]
#   0%|          | 0.0/100 [00:08<00:05, 19.98it/s, Warming up]
# 100%|██████████| 100.0/100 [00:08<00:00, 18.25it/s, EnergyPlus Run Time=00hr 00min  8.67sec]
#   0%|          | 0.0/100 [00:08<00:05, 19.98it/s, Warming up]
# 100%|██████████| 100.0/100 [00:08<00:00, 18.25it/s, EnergyPlus, Version 23.2.0-7636e6b3e9, YMD=2024.11.16 10:16]
#   0%|          | 0.0/100 [00:08<00:05, 19.98it/s, ...for Sizing Period: #1 SUMMER DESIGN DAY IN SITE (01-01:31-12) JUL]
#   0%|          | 0.0/100 [00:09<00:05, 18.25it/s, Proceeding with Initializing Solar Calculations]
#   0%|          | 0.0/100 [00:09<00:05, 19.98it/s, Warming up]
#   0%|          | 0.0/100 [00:09<00:05, 18.25it/s, Warming up]
#   0%|          | 0.0/100 [00:09<00:05, 19.98it/s, Warming up]
#   0%|          | 0.0/100 [00:09<00:05, 19.98it/s, ...for Sizing Period: #2 WINTER DESIGN DAY IN SITE (01-01:31-12)]
#   0%|          | 0.0/100 [00:09<00:05, 19.98it/s, Calculating System sizing]
#   0%|          | 0.0/100 [00:09<00:05, 19.98it/s, Initializing Simulation]
#   0%|          | 0.0/100 [00:09<00:05, 19.98it/s, Warming up {1}]
#   0%|          | 0.0/100 [00:09<00:05, 18.25it/s, ...for Sizing Period: #1 SUMMER DESIGN DAY IN SITE (01-01:31-12) JUL]/home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   0%|          | 0.0/100 [00:09<00:05, 18.07it/s, ...for Sizing Period: #1 SUMMER DESIGN DAY IN SITE (01-01:31-12) JUL]
#   0%|          | 0.0/100 [00:09<00:05, 19.98it/s, Warming up {3}]
#   0%|          | 0.0/100 [00:09<00:05, 19.98it/s, Warming up {4}]
#   0%|          | 0.0/100 [00:09<00:05, 19.98it/s, Warming up {6}]
#   3%|▎         | 3.0/100 [00:09<00:18,  5.17it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]/home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728698) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728698) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728698) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728698) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728698) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728698) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728698) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=1728698) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   0%|          | 0.0/100 [00:10<00:05, 18.07it/s, ...for Sizing Period: #2 WINTER DESIGN DAY IN SITE (01-01:31-12)]
#   0%|          | 0.0/100 [00:10<00:05, 18.25it/s, ...for Sizing Period: #2 WINTER DESIGN DAY IN SITE (01-01:31-12)]
#   0%|          | 0.0/100 [00:10<00:05, 18.25it/s, Initializing Simulation]
#   0%|          | 0.0/100 [00:10<00:05, 18.07it/s, Warming up {1}]
#   3%|▎         | 3.0/100 [00:10<00:19,  5.01it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]/home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   3%|▎         | 3.0/100 [00:10<00:19,  5.05it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]/home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#  62%|██████▏   | 62.0/100 [00:07<00:03, 10.99it/s, Updating Shadowing Calculations, Start Date=07/21/2002]   [repeated 3x across cluster]
#   0%|          | 0.0/100 [00:11<00:07, 14.22it/s, Setting up Surface Reporting Variables]
#  65%|██████▌   | 65.0/100 [00:07<00:03, 10.99it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)] [repeated 3x across cluster]
#   0%|          | 0.0/100 [00:11<00:07, 14.22it/s, Warming up]
# (RolloutWorker pid=1728701)   _warnings_.warn( [repeated 56x across cluster]
# (RolloutWorker pid=1728701) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable [repeated 15x across cluster]
# (RolloutWorker pid=1728698) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable [repeated 14x across cluster]
#  91%|█████████ | 91.0/100 [00:10<00:00, 11.00it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)] [repeated 33x across cluster]
#   0%|          | 0.0/100 [00:12<00:07, 14.22it/s, Adjusting Air System Sizing]
#   0%|          | 0.0/100 [00:12<00:07, 14.22it/s, Initializing Simulation]
#   6%|▌         | 6.0/100 [00:11<00:28,  3.27it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]
#   6%|▌         | 6.0/100 [00:12<00:29,  3.23it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]
#   3%|▎         | 3.0/100 [00:12<00:20,  4.73it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]
#  94%|█████████▍| 94.0/100 [00:10<00:00, 11.00it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)] [repeated 3x across cluster]
# 100%|██████████| 100.0/100 [00:10<00:00, 14.22it/s, EnergyPlus, Version 23.2.0-7636e6b3e9, YMD=2024.11.16 10:16] [repeated 2x across cluster]
#   0%|          | 0.0/100 [00:11<00:07, 14.22it/s, Warming up] [repeated 7x across cluster]
#   0%|          | 0.0/100 [00:11<00:07, 14.22it/s, Warming up] [repeated 4x across cluster]
#   0%|          | 0.0/100 [00:09<00:05, 18.07it/s, Proceeding with Initializing Solar Calculations]
#   0%|          | 0.0/100 [00:09<00:05, 18.07it/s, Warming up]
#   0%|          | 0.0/100 [00:11<00:07, 14.22it/s, Warming up] [repeated 4x across cluster]
#   0%|          | 0.0/100 [00:12<00:07, 14.22it/s, Warming up {1}]                          [repeated 2x across cluster]
#   0%|          | 0.0/100 [00:11<00:07, 14.22it/s, ...for Sizing Period: #1 SUMMER DESIGN DAY IN SITE (01-01:31-12) JUL]
#   0%|          | 0.0/100 [00:12<00:07, 14.22it/s, Warming up {6}] [repeated 5x across cluster]
#   0%|          | 0.0/100 [00:12<00:07, 14.22it/s, Warming up {4}] [repeated 5x across cluster]
# (RolloutWorker pid=1728701) /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:370: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable [repeated 15x across cluster]
#   0%|          | 0.0/100 [00:11<00:07, 14.22it/s, ...for Sizing Period: #2 WINTER DESIGN DAY IN SITE (01-01:31-12)]
#  12%|█▏        | 12.0/100 [00:18<00:41,  2.10it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)] [repeated 9x across cluster]
#  21%|██        | 21.0/100 [00:24<00:47,  1.67it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)] [repeated 12x across cluster]
#  29%|██▉       | 28.999999999999996/100 [00:29<00:47,  1.49it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)] [repeated 12x across cluster]
#  41%|████      | 41.0/100 [00:35<00:37,  1.57it/s, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)] [repeated 12x across cluster]
# (PPO pid=1728512) 2024-11-16 10:16:53,012	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                           </th><th style="text-align: right;">  agent_timesteps_total</th><th>counters                                                                                                                          </th><th>custom_metrics  </th><th>env_runners                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        </th><th>episode_media  </th><th>info                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# </thead>
# <tbody>
# <tr><td>PPO_MultiAgentBuildingEnv_c81eb_00000</td><td style="text-align: right;">                  32000</td><td>{&#x27;num_env_steps_sampled&#x27;: 4000, &#x27;num_env_steps_trained&#x27;: 4000, &#x27;num_agent_steps_sampled&#x27;: 32000, &#x27;num_agent_steps_trained&#x27;: 32000}</td><td>{}              </td><td>{&#x27;episode_reward_max&#x27;: nan, &#x27;episode_reward_min&#x27;: nan, &#x27;episode_reward_mean&#x27;: nan, &#x27;episode_len_mean&#x27;: nan, &#x27;episode_media&#x27;: {}, &#x27;episodes_timesteps_total&#x27;: 0, &#x27;policy_reward_min&#x27;: {}, &#x27;policy_reward_max&#x27;: {}, &#x27;policy_reward_mean&#x27;: {}, &#x27;custom_metrics&#x27;: {}, &#x27;hist_stats&#x27;: {&#x27;episode_reward&#x27;: [], &#x27;episode_lengths&#x27;: []}, &#x27;sampler_perf&#x27;: {}, &#x27;num_faulty_episodes&#x27;: 0, &#x27;connector_metrics&#x27;: {}, &#x27;num_episodes&#x27;: 0, &#x27;episode_return_max&#x27;: nan, &#x27;episode_return_min&#x27;: nan, &#x27;episode_return_mean&#x27;: nan, &#x27;episodes_this_iter&#x27;: 0}</td><td>{}             </td><td>{&#x27;learner&#x27;: {&#x27;1FEAST&#x27;: {&#x27;learner_stats&#x27;: {&#x27;allreduce_latency&#x27;: 0.0, &#x27;grad_gnorm&#x27;: 1.2012871546515573, &#x27;cur_kl_coeff&#x27;: 0.20000000000000004, &#x27;cur
#  44%|████▍     | 44.0/100 [01:16<04:15,  4.56s/it, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)] [repeated 6x across cluster]
# (PPO pid=1728516) 2024-11-16 10:16:55,083	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
#  53%|█████▎    | 53.0/100 [01:21<01:32,  1.98s/it, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)] [repeated 10x across cluster]
#  62%|██████▏   | 62.0/100 [01:27<00:42,  1.11s/it, Updating Shadowing Calculations, Start Date=07/21/2002]
#  56%|█████▌    | 56.00000000000001/100 [01:26<01:09,  1.58s/it, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)] [repeated 11x across cluster]
#  65%|██████▌   | 65.0/100 [01:29<00:33,  1.03it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)]
#  68%|██████▊   | 68.0/100 [01:31<00:27,  1.16it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)]
#  62%|██████▏   | 62.0/100 [01:29<00:41,  1.10s/it, Updating Shadowing Calculations, Start Date=07/21/2002]   [repeated 3x across cluster]
#  59%|█████▉    | 59.0/100 [01:27<00:53,  1.30s/it, Starting Simulation at 07/01/2002 for SITE (01-01:31-12)]              [repeated 2x across cluster]
#  65%|██████▌   | 65.0/100 [01:31<00:33,  1.04it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)] [repeated 3x across cluster]
#  76%|███████▌  | 76.0/100 [01:37<00:19,  1.24it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)] [repeated 10x across cluster]
#  82%|████████▏ | 82.0/100 [01:43<00:13,  1.37it/s, Continuing Simulation at 07/21/2002 for SITE (01-01:31-12)] [repeated 12x across cluster]
# 2024-11-16 10:18:17,629	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-11-16 10:18:17,641	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/AD/user/ray_results/PPO_2024-11-16_10-16-00' in 0.0108s.
# 2024-11-16 10:18:27,648	INFO tune.py:1041 -- Total run time: 145.55 seconds (135.51 seconds for the tuning loop).
# 2024-11-16 10:18:27,649	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: Tuner.restore(path="/home/AD/user/ray_results/PPO_2024-11-16_10-16-00", trainable=...)
# (raylet) [2024-11-16 10:19:01,573 E 1727084 1727084] (raylet) node_manager.cc:3065: 2 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 8de563a5b1ccc2835103126c076a2f03a34a89dbde33d13de438560a, IP: 192.168.200.249) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.200.249`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.

# %%
best_result = results.get_best_result()
print("Best Hyperparameters found: ", best_result)
# Out:
# 2024-11-16 09:19:59,228	WARNING experiment_analysis.py:558 -- Could not find best trial. Did you pass the correct `metric` parameter?
#   0%|          | 0.0/100 [00:10<00:02, 35.10it/s, Warming up]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 best_result = results.get_best_result()
#       2 print("Best Hyperparameters found: ", best_result)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/tune/result_grid.py:161, in ResultGrid.get_best_result(self, metric, mode, scope, filter_nan_and_inf)
#     150     error_msg = (
#     151         "No best trial found for the given metric: "
#     152         f"{metric or self._experiment_analysis.default_metric}. "
#     153         "This means that no trial has reported this metric"
#     154     )
#     155     error_msg += (
#     156         ", or all values reported for this metric are NaN. To not ignore NaN "
#     157         "values, you can set the `filter_nan_and_inf` arg to False."
#     158         if filter_nan_and_inf
#     159         else "."
#     160     )
# --> 161     raise RuntimeError(error_msg)
#     163 return self._trial_to_result(best_trial)
#
# RuntimeError: No best trial found for the given metric: env_runners/episode_reward_mean. This means that no trial has reported this metric, or all values reported for this metric are NaN. To not ignore NaN values, you can set the `filter_nan_and_inf` arg to False.

# %%
from ray.rllib.algorithms.callbacks import DefaultCallbacks
from controllables.core import BaseVariable
from controllables.core.tools.records import VariableRecords
from ray.rllib.algorithms.ppo import PPO, PPOConfig
from ray.rllib.algorithms.callbacks import DefaultCallbacks

from controllables.core import BaseVariable, ComputedVariable
from controllables.core.tools.records import VariableRecords

import pythermalcomfort as pytc
import numpy as _numpy_


from controllables.energyplus import Actuator, OutputVariable, OutputMeter

class PMVVariable(BaseVariable):
    def __init__(
        self, 
        tdb: BaseVariable,
        tr: BaseVariable,
        rh: BaseVariable,
        metab_rate=1.5, clothing=.5, pmv_limit=.5,
    ):
        self.tdb = tdb
        self.tr = tr
        self.rh = rh
        self._metab_rate = _numpy_.asarray(metab_rate)
        self._clothing = _numpy_.asarray(clothing)
        self._pmv_limit = _numpy_.asarray(pmv_limit)
    
    @property
    def value(self):
        res = pytc.models.pmv_ppd(
            tdb=self.tdb.value, 
            tr=self.tr.value, 
            # calculate relative air speed
            vr=pytc.utilities.v_relative(v=0.1, met=self._metab_rate), 
            rh=self.rh.value, 
            met=self._metab_rate, 
            # calculate dynamic clothing
            clo=pytc.utilities.clo_dynamic(clo=self._clothing, met=self._metab_rate),
            limit_inputs=False,
        )['pmv']

        return res

class PlottingCallbacks(DefaultCallbacks):
    def __init__(self):
        self.env_records: dict[object, VariableRecords] = None

    def on_episode_start(self, *, episode, worker, **kwargs):
        env: MultiAgentBuildingEnv = worker.env
        system = env.system
        if self.env_records is None:
            system.add('logging:progress')
            self.env_records = dict()
            for agent_ref in env.agents:
                if agent_ref == 'CHILLER' or agent_ref == 'AHU':
                    # self.env_records[agent_ref] = records = VariableRecords({
                    # 'AHU COOLING COIL': system[OutputVariable.Ref('Cooling Coil Total Cooling Rate', 'AIR LOOP AHU COOLING COIL')],
                    # 'Electricity': system[OutputMeter.Ref('Electricity:HVAC')]
                    # }, maxlen=10_000)
                    pass
                else:
                    tdb = env.agents[agent_ref].observation['temperature:drybulb']
                    tr = env.agents[agent_ref].observation['temperature:radiant']
                    rh = env.agents[agent_ref].observation['humidity']
                    pmv = PMVVariable(tdb=tdb, tr=tr, rh=rh)
                    self.env_records[agent_ref] = records = VariableRecords({
                        '🕰️': system['time'],
                        '🍩': env.agents[agent_ref].reward,
                        'pmv': pmv,
                        'occupancy': env.agents[agent_ref].observation['Office Occupancy'],
                        # 'tstat': env.agents[agent_ref].action['thermostat'],
                        'temp': tdb,
                        # 'AHU COOLING COIL': system[OutputVariable.Ref('Cooling Coil Total Cooling Rate', 'AIR LOOP AHU COOLING COIL')],
                        'elec': system[OutputMeter.Ref('Electricity:HVAC')],
                    }, maxlen=10_000)
                    # display(
                    #     records.plot.scatter(x='🕰️', y='pv', label=repr(agent_ref))
                    #     .watch(records.events['change'] % 1_000)
                    # )

    def on_episode_step(self, *, episode, **kwargs):
        for _, env_records in self.env_records.items():
            env_records.poll()

    def on_episode_end(self, *, episode, **kwargs):
        for agent_ref, env_records in self.env_records.items():
            env_records.dataframe().to_csv(f'datasave/20241113/records_train_slope_angle_distant_elc_changed-{agent_ref}.csv', index=False)

# %%
config_eval = (
    MonoAgentBuildingEnv.get_algo_config(
        PPOConfig()
        .rollouts(
            num_rollout_workers=4, 
            rollout_fragment_length='auto',
        )
        .resources(num_gpus=1/2)
    )
    .env_runners(
        num_env_runners=0,
        create_env_on_local_worker=True,
    )
    .evaluation(
        evaluation_duration=1,
        evaluation_duration_unit='episodes',
        #evaluation_interval=1,
        evaluation_num_env_runners=0,
    )
    .callbacks(PlottingCallbacks)
)

algo_eval = PPO(config_eval)
#algo_eval.restore(best_result.checkpoint)
algo_eval.restore('/home/AD/user/ray_results/PPO_2024-11-14_17-33-56/PPO_MonoAgentBuildingEnv_a0b84_00001_1_2024-11-14_17-33-57/checkpoint_000049')
#algo_eval.restore("/home/AD/user/ray_results/PPO_2024-10-18_15-32-34/PPO_UserMultiAgentEnv_331fb_00000_0_2024-10-18_15-32-35/checkpoint_000013")
# Out:
# 2024-11-15 05:44:55,191	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_rollout_workers)` has been deprecated. Use `AlgorithmConfig.env_runners(num_env_runners)` instead. This will raise an error in the future!
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:555: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2024-11-15 05:44:55,287	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# 2024-11-15 05:44:55,300	INFO trainable.py:583 -- Restored on 192.168.200.249 from checkpoint: Checkpoint(filesystem=local, path=/home/AD/user/ray_results/PPO_2024-11-14_17-33-56/PPO_MonoAgentBuildingEnv_a0b84_00001_1_2024-11-14_17-33-57/checkpoint_000049)
# /usr/lib/python3.11/tempfile.py:1043: ResourceWarning: Implicitly cleaning up <TemporaryDirectory '/tmp/.energyplus_output_ptv97bl8'>
#   _warnings.warn(warn_message, ResourceWarning)
# /usr/lib/python3.11/tempfile.py:1043: ResourceWarning: Implicitly cleaning up <TemporaryDirectory '/tmp/.energyplus_output_z9131ogb'>
#   _warnings.warn(warn_message, ResourceWarning)
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='0FGROUNDFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Schedule Value', key='Office_OpenOff_Occ')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(

# %%
for _ in range(2):
    algo_eval.evaluate()
# Out:
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOOREAST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='0FGROUNDFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOOREAST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='1FFIRSTFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='1FFIRSTFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='1FFIRSTFLOORWEST:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Air Relative Humidity', key='0FGROUNDFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='0FGROUNDFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/energyplus/variables.py:345: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Radiant Temperature', key='0FGROUNDFLOORWEST1:OPENOFFICE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
#   0%|          | 0/100 [00:00<?, ?it/s]
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/controllables/core/tools/gymnasium/spaces.py:224: RuntimeWarning: overflow encountered in cast
#   return _numpy_.array(
