# %%
# %env KERAS_BACKEND=torch

from typing import TypedDict, Unpack
import functools as _functools_

from more_itertools import sliding_window 
from keras import Model, Sequential, layers, KerasTensor

# TODO use keras!!!!
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
####


class PVPredictor:

    class Input(TypedDict):
        out_w: KerasTensor
        r"""The previous photovoltaic power outputs (W)"""

    class Output(TypedDict):
        out_w: KerasTensor
        r"""The next photovoltaic power output (W)"""

    def _make_model(self, **model_kwds):
        # TODO rm
        
        inputs: PVPredictor.Input = {
            'out_w': layers.Input(shape=(None, )),
            # 'drytemp_c': layers.Input(shape=(None, 1)),
            # 'airpress_pa': layers.Input(shape=(None, 1)),
            # 'windspeed_mps': layers.Input(shape=(None, 1)),
            # 'winddir_deg': layers.Input(shape=(None, 1)),
            # 'diffsolar_wpsqm': layers.Input(shape=(None, )),
            'directsolar_wpsqm': layers.Input(shape=(None, )),
            # 'solazim_deg': layers.Input(shape=(None, 1)),
            # 'solalti_deg': layers.Input(shape=(None, 1)),
        }

        concatenated_inputs = layers.Concatenate(axis=-1)(
            list(layers.Reshape((-1, 1))(x) for x in inputs.values())
        )
        body = Sequential([
            layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
            layers.MaxPooling1D(pool_size=2),
            layers.Dropout(0.5),
            layers.Bidirectional(layers.LSTM(100, return_sequences=True)),
            layers.Dropout(0.5),
            layers.Bidirectional(layers.LSTM(100, return_sequences=False)),
            layers.Dropout(0.5),
        ])
        outputs: PVPredictor.Output = {
            'out_w': layers.Lambda(lambda x: x[..., 0])(
                layers.Dense(1)(body(concatenated_inputs))
            ),
        }

        model = Model(inputs=inputs, outputs=outputs, **model_kwds)
        model.compile(optimizer='adam', loss='mse')
        return model

    def __init__(self):
        self.model = self._make_model()

    @_functools_.cached_property
    def experience(self) -> list[tuple[Input, Output]]:
        return list()
    
    def train(self, **fit_kwds):
        truths = [
            (input_curr, {'out_w': input_next['out_w']})
            for (input_curr, _), (input_next, _) in 
            sliding_window(self.experience, n=2)
        ]

        if len(truths) == 0:
            return
        return self.model.fit(
            (x for x in truths),
            shuffle=False,
            **fit_kwds,
        )
    
    def __call__(self, inputs: Input) -> Output:
        output_pred = self.model(inputs, training=False)
        self.experience.append((inputs, output_pred))
        return output_pred
# Out:
# env: KERAS_BACKEND=torch

# %%
PVPredictor().model(
    layers.Input(shape=(20, 1))
)
# Out:
# 2024-11-03 05:15:08.536164: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1730610908.547564   51439 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1730610908.550923   51439 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-03 05:15:08.563455: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:106: UserWarning: When providing `inputs` as a dict, all keys in the dict must match the names of the corresponding tensors. Received key 'out_w' mapping to value <KerasTensor shape=(None, None), dtype=float32, sparse=False, name=keras_tensor> which has name 'keras_tensor'. Change the tensor name to 'out_w' (via `Input(..., name='out_w')`)
#   warnings.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:106: UserWarning: When providing `inputs` as a dict, all keys in the dict must match the names of the corresponding tensors. Received key 'directsolar_wpsqm' mapping to value <KerasTensor shape=(None, None), dtype=float32, sparse=False, name=keras_tensor_1> which has name 'keras_tensor_1'. Change the tensor name to 'directsolar_wpsqm' (via `Input(..., name='directsolar_wpsqm')`)
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 PVPredictor().model(
#       2     layers.Input(shape=(20, 1))
#       3 )
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/input_spec.py:160, in assert_input_compatibility(input_spec, inputs, layer_name)
#     158 inputs = tree.flatten(inputs)
#     159 if len(inputs) != len(input_spec):
# --> 160     raise ValueError(
#     161         f'Layer "{layer_name}" expects {len(input_spec)} input(s),'
#     162         f" but it received {len(inputs)} input tensors. "
#     163         f"Inputs received: {inputs}"
#     164     )
#     165 for input_index, (x, spec) in enumerate(zip(inputs, input_spec)):
#     166     if spec is None:
#
# ValueError: Layer "functional_1" expects 2 input(s), but it received 1 input tensors. Inputs received: [<KerasTensor shape=(None, 20, 1), dtype=float32, sparse=False, name=keras_tensor_18>]

# %%
PVPredictor()._model(np.zeros((1, 5, 1)))
# Out:
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:106: UserWarning: When providing `inputs` as a dict, all keys in the dict must match the names of the corresponding tensors. Received key 'out_w' mapping to value <KerasTensor shape=(None, None), dtype=float32, sparse=False, name=keras_tensor_484> which has name 'keras_tensor_484'. Change the tensor name to 'out_w' (via `Input(..., name='out_w')`)
#   warnings.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:106: UserWarning: When providing `inputs` as a dict, all keys in the dict must match the names of the corresponding tensors. Received key 'directsolar_wpsqm' mapping to value <KerasTensor shape=(None, None), dtype=float32, sparse=False, name=keras_tensor_485> which has name 'keras_tensor_485'. Change the tensor name to 'directsolar_wpsqm' (via `Input(..., name='directsolar_wpsqm')`)
#   warnings.warn(
# tensor([[0.]], device='cuda:0', grad_fn=<AddBackward0>)

# %%
np.array([[[1], [2], [3]]]).shape
# Out:
# (1, 3, 1)

# %%
import numpy as np

# TODO mv doctest
# PVPredictor._make_model()({
#     'out_w': np.array([[1, 2, 3, 4]]),
# })

# %%
# predictor = PVPredictor()

# for _ in range(20):
#     predictor({
#         'out_w': np.array([[1, 2, 3, 4, 7]]),
#     })
#     if len(predictor.experience) >= 10:
#         predictor.train()
#         predictor.experience.clear()

# %%
from collections import deque

class PVTrackingPredictor:
    class Observation(TypedDict):
        out_w: float
        r"""The current photovoltaic power output (W)"""

    class Result(TypedDict):
        out_w: float
        r"""The next photovoltaic power output (W)"""

    def __init__(
        self, 
        lookback: int | None = None, 
        **predictor_kwds,
    ):
        self.predictor = PVPredictor(**predictor_kwds)
        self.history = deque(maxlen=lookback)

    def __call__(
        self, 
        observation: Observation, 
        lookback: int | None = None,
        experience_len: int = 1,
        **fit_kwds,
    ) -> Result | None:
        self.history.append(observation)
        if len(self.history) < (
            lookback 
            if lookback is not None else 
            # TODO what if this is None as well??
            self.history.maxlen
        ):
            return None

        if len(self.predictor.experience) >= experience_len:
            self.predictor.train(**fit_kwds)
            self.predictor.experience.clear()
            
        predictor_inputs: PVPredictor.Input = {
            k: np.array([[x[k] for x in self.history]])
            for k in ('out_w', 'directsolar_wpsqm')
        }
        res = self.predictor(predictor_inputs)        
        # TODO proc res
        return {
            'out_w': res['out_w'][0],
        }

# %%
# tracking_predictor = PVTrackingPredictor(lookback=10)

# for out_w in range(10):
#     print(tracking_predictor({'out_w': out_w}, experience_len=100))

# %%
import pandas as pd
df = pd.read_csv('filtered_solar_data.csv')
df
# Out:
#                           clock   pv  Drybulb_Temperature   Air_Pressure  \
# 0     1999-07-01 00:10:00+00:00  0.0            27.633333  100700.000000
# 1     1999-07-01 00:20:00+00:00  0.0            27.266667  100700.000000
# 2     1999-07-01 00:30:00+00:00  0.0            26.900000  100700.000000
# 3     1999-07-01 00:40:00+00:00  0.0            26.533333  100700.000000
# 4     1999-07-01 00:50:00+00:00  0.0            26.166667  100700.000000
# ...                         ...  ...                  ...            ...
# 4315  1999-07-30 23:20:00+00:00  0.0            26.233333  100533.333333
# 4316  1999-07-30 23:30:00+00:00  0.0            26.000000  100550.000000
# 4317  1999-07-30 23:40:00+00:00  0.0            25.766667  100566.666667
# 4318  1999-07-30 23:50:00+00:00  0.0            25.533333  100583.333333
# 4319  1999-07-31 00:00:00+00:00  0.0            25.300000  100600.000000
#
#       Wind_Speed  Wind_Direction  Diffuse_Solar_Radiation  \
# 0       0.583333      211.666667                      0.0
# 1       0.466667      233.333333                      0.0
# 2       0.350000      255.000000                      0.0
# 3       0.233333      276.666667                      0.0
# 4       0.116667      298.333333                      0.0
# ...          ...             ...                      ...
# 4315    1.900000      140.000000                      0.0
# 4316    1.800000      140.000000                      0.0
# 4317    1.700000      140.000000                      0.0
# 4318    1.600000      140.000000                      0.0
# 4319    1.500000      140.000000                      0.0
#
#       Direct_Solar_Radiation  Solar_Azimuth_Angle  Solar_Altitude_Angle  \
# 0                        0.0            28.851525            -61.751482
# 1                        0.0            24.534594            -62.875105
# 2                        0.0            19.862324            -63.820269
# 3                        0.0            14.867243            -64.566991
# 4                        0.0             9.606702            -65.097355
# ...                      ...                  ...                   ...
# 4315                     0.0           307.787278            -56.248959
# 4316                     0.0           310.292169            -58.190742
# 4317                     0.0           313.134014            -60.057104
# 4318                     0.0           316.361694            -61.832944
# 4319                     0.0           320.026942            -63.499955
#
#                Clock
# 0     07-01 00:10:00
# 1     07-01 00:20:00
# 2     07-01 00:30:00
# 3     07-01 00:40:00
# 4     07-01 00:50:00
# ...              ...
# 4315  07-30 23:20:00
# 4316  07-30 23:30:00
# 4317  07-30 23:40:00
# 4318  07-30 23:50:00
# 4319  07-31 00:00:00
#
# [4320 rows x 11 columns]

# %%
import tensorflow as _tensorflow_

layers.Normalization().adapt

_tensorflow_.data.Dataset.from_tensor_slices({'a': np.array([[1], [2]])})
_tensorflow_.data.Dataset.from_tensor_slices({'x': {'a': np.array([[1], [2]])}})
# Out:
# <_TensorSliceDataset element_spec={'x': {'a': TensorSpec(shape=(1,), dtype=tf.int64, name=None)}}>

# %%
#layers.Normalization().adapt({'x': {'a': np.array([[1], [2]])}})
#.adapt({'a': [[1], [2]]})

# %%
import pandas as pd
df = pd.read_csv('filtered_solar_data.csv')
#features = ['pv']
#X = df[features]#.values

tracking_predictor = PVTrackingPredictor(lookback=1_000)

for out_w, directsolar_wpsqm in zip(df['pv'], df['Direct_Solar_Radiation']):
    (tracking_predictor(
        {'out_w': out_w, 'directsolar_wpsqm': directsolar_wpsqm}, 
        experience_len=10,
        epochs=10,
    ))
# Out:
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:106: UserWarning: When providing `inputs` as a dict, all keys in the dict must match the names of the corresponding tensors. Received key 'out_w' mapping to value <KerasTensor shape=(None, None), dtype=float32, sparse=False, name=keras_tensor_18> which has name 'keras_tensor_18'. Change the tensor name to 'out_w' (via `Input(..., name='out_w')`)
#   warnings.warn(
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:106: UserWarning: When providing `inputs` as a dict, all keys in the dict must match the names of the corresponding tensors. Received key 'directsolar_wpsqm' mapping to value <KerasTensor shape=(None, None), dtype=float32, sparse=False, name=keras_tensor_19> which has name 'keras_tensor_19'. Change the tensor name to 'directsolar_wpsqm' (via `Input(..., name='directsolar_wpsqm')`)
#   warnings.warn(
# Epoch 1/10
# /home/AD/user/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/torch/numpy.py:1143: UserWarning: No PYTORCH_KERNEL_CACHE_PATH or HOME environment variable set! This disables kernel caching. (Triggered internally at ../aten/src/ATen/native/cuda/jit_utils.cpp:1426.)
#   return cast(torch.prod(x, dtype=to_torch_dtype(compute_dtype)), dtype)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 25790714478592.0000
# Epoch 2/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 164us/step
# Epoch 3/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 136us/step
# Epoch 4/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 97us/step
# Epoch 5/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 88us/step
# Epoch 6/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 85us/step
# Epoch 7/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step
# Epoch 8/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step
# Epoch 9/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step
# Epoch 10/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 98us/step
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 25790693507072.0000
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 73us/step
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 71us/step
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 83us/step
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 65us/step
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 64us/step
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 67us/step
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 73us/step
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 61us/step
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 63us/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       6 tracking_predictor = PVTrackingPredictor(lookback=1_000)
#       8 for out_w, directsolar_wpsqm in zip(df['pv'], df['Direct_Solar_Radiation']):
# ----> 9     (tracking_predictor(
#      10         {'out_w': out_w, 'directsolar_wpsqm': directsolar_wpsqm},
#      11         experience_len=10,
#      12         epochs=10,
#      13     ))
#
# Cell In[5], line 44, in PVTrackingPredictor.__call__(self, observation, lookback, experience_len, **fit_kwds)
#      38     self.predictor.experience.clear()
#      40 predictor_inputs: PVPredictor.Input = {
#      41     k: np.array([[x[k] for x in self.history]])
#      42     for k in ('out_w', 'directsolar_wpsqm')
#      43 }
# ---> 44 res = self.predictor(predictor_inputs)
#      45 # TODO proc res
#      46 return {
#      47     'out_w': res['out_w'][0],
#      48 }
#
# Cell In[2], line 83, in PVPredictor.__call__(self, inputs)
#      82 def __call__(self, inputs: Input) -> Output:
# ---> 83     output_pred = self.model(inputs, training=False)
#      84     self.experience.append((inputs, output_pred))
#      85     return output_pred
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py:899, in Layer.__call__(self, *args, **kwargs)
#     897         outputs = super().__call__(*args, **kwargs)
#     898 else:
# --> 899     outputs = super().__call__(*args, **kwargs)
#     900 # Change the layout for the layer output if needed.
#     901 # This is useful for relayout intermediate tensor in the model
#     902 # to achieve the optimal performance.
#     903 distribution = distribution_lib.distribution()
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/torch/layer.py:44, in TorchLayer.forward(self, *args, **kwargs)
#      43 def forward(self, *args, **kwargs):
# ---> 44     return Operation.__call__(self, *args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:182, in Functional.call(self, inputs, training, mask)
#     180         if mask is not None:
#     181             backend.set_keras_mask(x, mask)
# --> 182 outputs = self._run_through_graph(
#     183     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184 )
#     185 return unpack_singleton(outputs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:584, in operation_fn.<locals>.call(*args, **kwargs)
#     578 if (
#     579     hasattr(operation, "_call_has_training_arg")
#     580     and operation._call_has_training_arg
#     581     and training is not None
#     582 ):
#     583     kwargs["training"] = training
# --> 584 return operation(*args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py:899, in Layer.__call__(self, *args, **kwargs)
#     897         outputs = super().__call__(*args, **kwargs)
#     898 else:
# --> 899     outputs = super().__call__(*args, **kwargs)
#     900 # Change the layout for the layer output if needed.
#     901 # This is useful for relayout intermediate tensor in the model
#     902 # to achieve the optimal performance.
#     903 distribution = distribution_lib.distribution()
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/torch/layer.py:44, in TorchLayer.forward(self, *args, **kwargs)
#      43 def forward(self, *args, **kwargs):
# ---> 44     return Operation.__call__(self, *args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/sequential.py:213, in Sequential.call(self, inputs, training, mask)
#     211 def call(self, inputs, training=None, mask=None):
#     212     if self._functional:
# --> 213         return self._functional.call(inputs, training=training, mask=mask)
#     215     # Fallback: Just apply the layer sequence.
#     216     # This typically happens if `inputs` is a nested struct.
#     217     for layer in self.layers:
#     218         # During each iteration, `inputs` are the inputs to `layer`, and
#     219         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     220         # end of each iteration `inputs` is set to `outputs` to prepare for
#     221         # the next layer.
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:182, in Functional.call(self, inputs, training, mask)
#     180         if mask is not None:
#     181             backend.set_keras_mask(x, mask)
# --> 182 outputs = self._run_through_graph(
#     183     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184 )
#     185 return unpack_singleton(outputs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py:584, in operation_fn.<locals>.call(*args, **kwargs)
#     578 if (
#     579     hasattr(operation, "_call_has_training_arg")
#     580     and operation._call_has_training_arg
#     581     and training is not None
#     582 ):
#     583     kwargs["training"] = training
# --> 584 return operation(*args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py:899, in Layer.__call__(self, *args, **kwargs)
#     897         outputs = super().__call__(*args, **kwargs)
#     898 else:
# --> 899     outputs = super().__call__(*args, **kwargs)
#     900 # Change the layout for the layer output if needed.
#     901 # This is useful for relayout intermediate tensor in the model
#     902 # to achieve the optimal performance.
#     903 distribution = distribution_lib.distribution()
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/torch/layer.py:44, in TorchLayer.forward(self, *args, **kwargs)
#      43 def forward(self, *args, **kwargs):
# ---> 44     return Operation.__call__(self, *args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/bidirectional.py:221, in Bidirectional.call(self, sequences, initial_state, mask, training)
#     216     forward_state, backward_state = None, None
#     218 y = self.forward_layer(
#     219     forward_inputs, initial_state=forward_state, **kwargs
#     220 )
# --> 221 y_rev = self.backward_layer(
#     222     backward_inputs, initial_state=backward_state, **kwargs
#     223 )
#     225 if self.return_state:
#     226     states = tuple(y[1:] + y_rev[1:])
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py:899, in Layer.__call__(self, *args, **kwargs)
#     897         outputs = super().__call__(*args, **kwargs)
#     898 else:
# --> 899     outputs = super().__call__(*args, **kwargs)
#     900 # Change the layout for the layer output if needed.
#     901 # This is useful for relayout intermediate tensor in the model
#     902 # to achieve the optimal performance.
#     903 distribution = distribution_lib.distribution()
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/torch/layer.py:44, in TorchLayer.forward(self, *args, **kwargs)
#      43 def forward(self, *args, **kwargs):
# ---> 44     return Operation.__call__(self, *args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/lstm.py:570, in LSTM.call(self, sequences, initial_state, mask, training)
#     569 def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 570     return super().call(
#     571         sequences, mask=mask, training=training, initial_state=initial_state
#     572     )
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:406, in RNN.call(self, sequences, initial_state, mask, training)
#     400 # Prepopulate the dropout state so that the inner_loop is stateless
#     401 # this is particularly important for JAX backend.
#     402 self._maybe_config_dropout_masks(
#     403     self.cell, sequences[:, 0, :], initial_state
#     404 )
# --> 406 last_output, outputs, states = self.inner_loop(
#     407     sequences=sequences,
#     408     initial_state=initial_state,
#     409     mask=mask,
#     410     training=training,
#     411 )
#     412 last_output = ops.cast(last_output, self.compute_dtype)
#     413 outputs = ops.cast(outputs, self.compute_dtype)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/lstm.py:565, in LSTM.inner_loop(self, sequences, initial_state, mask, training)
#     558 if self.use_cudnn is True:
#     559     raise ValueError(
#     560         "use_cudnn=True was specified, "
#     561         "but cuDNN is not supported for this layer configuration "
#     562         "with this backend. Pass use_cudnn='auto' to fallback "
#     563         "to a non-cuDNN implementation."
#     564     )
# --> 565 return super().inner_loop(
#     566     sequences, initial_state, mask=mask, training=training
#     567 )
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:346, in RNN.inner_loop(self, sequences, initial_state, mask, training)
#     343 if not tree.is_nested(initial_state):
#     344     initial_state = [initial_state]
# --> 346 return backend.rnn(
#     347     step,
#     348     sequences,
#     349     initial_state,
#     350     go_backwards=self.go_backwards,
#     351     mask=mask,
#     352     unroll=self.unroll,
#     353     input_length=sequences.shape[1],
#     354     zero_output_for_mask=self.zero_output_for_mask,
#     355     return_all_outputs=self.return_sequences,
#     356 )
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/torch/rnn.py:346, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     344 output_ta_t = output_ta
#     345 new_states = states
# --> 346 while time < time_steps_t and it < max_iterations:
#     347     final_outputs = _step(time, output_ta_t, *new_states)
#     348     time, output_ta_t = final_outputs[:2]
#
# KeyboardInterrupt:

# %%
# %env KERAS_BACKEND=tensorflow

from typing import TypedDict, Unpack
import functools as _functools_

from more_itertools import sliding_window 
from keras import Model, Sequential, layers, KerasTensor

import numpy as np


class PVPredictorModel:
    @staticmethod
    def _invert_normalizer(normalizer: layers.Normalization):
        return layers.Normalization(
            axis=normalizer.axis, 
            invert=True,
            **(
                dict(
                    mean=normalizer.mean, 
                    variance=normalizer.variance,                 
                ) 
                if normalizer.built else 
                dict()
            ),
        )

    @_functools_.cached_property
    def _input_normalizer(self):
        return layers.Normalization(
            axis=-1,
        )
    
    @_functools_.cached_property
    def _output_normalizer(self):
        return layers.Normalization(
            axis=-1,
        )
    
    @_functools_.cached_property
    def _model(self):
        model = Sequential([
            layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
            layers.MaxPooling1D(pool_size=2),
            layers.Dropout(0.5),
            layers.Bidirectional(layers.LSTM(100, return_sequences=True)),
            layers.Dropout(0.5),
            layers.Bidirectional(layers.LSTM(100, return_sequences=False)),
            layers.Dropout(0.5),
            layers.Dense(1),
        ])
        model.compile(optimizer='adam', loss='mse')
        return model
    
    def fit(self, inputs, outputs, **kwargs):
        self._input_normalizer.adapt(inputs)
        self._output_normalizer.adapt(outputs)

        return self._model.fit(
            x=self._input_normalizer(inputs),
            y=self._output_normalizer(outputs),
            **kwargs,
        )
    
    def predict(self, inputs, **kwargs): 
        output = self._model.predict(
            self._input_normalizer(inputs),
            **kwargs,
        )

        denormalizer = self._invert_normalizer(
            self._output_normalizer
        )
        return denormalizer(output)



from collections import deque

class PVPredictor:
    class Observation(TypedDict):
        out_w: float
        r"""The current photovoltaic power output (W)"""

        @classmethod
        def to_array(cls, obs):
            if isinstance(obs, dict):
                return np.array(list(obs.values()))
            return np.array([cls.to_array(x) for x in obs])

    class Result(TypedDict):
        out_w: float
        r"""The next photovoltaic power output (W)"""

    Batch = list

    Truth = tuple[list[Observation], Result]

    def __init__(self, lookback: int | None = None):
        self.model = PVPredictorModel()
        self.observations = deque[self.Observation](maxlen=lookback)
    
    def fit(self, data_batch: Batch[Truth], **kwargs):
        inputs = np.array([
            [list(obs.values()) for obs in obss] 
            for obss, _ in data_batch
        ])
        outputs = np.array([
            list(res.values()) 
            for _, res in data_batch
        ])

        return self.model.fit(
            inputs, outputs,
            shuffle=False,
            **kwargs,
        )

    def predict(self, data_batch: Batch[list[Observation]], **kwargs) -> Batch[Result]:
        output_batch = self.model.predict(
            np.array([[list(obs.values()) for obs in batch] for batch in data_batch]),
            **kwargs,
        )
        res = [{'out_w': output[0]} for output in output_batch]
        return res

    @_functools_.cached_property
    def experience(self) -> list[Truth]:
        return list()
    
    @property
    def true_experience(self) -> list[Truth]:
        return [
            (obs_curr, {'out_w': obs_next[0]['out_w']})
            for (obs_curr, _), (obs_next, _) in 
            sliding_window(self.experience, n=2)
        ]
    
    def __call__(
        self, 
        observation: Observation,
        lookback: int | None = None,
        experience_len: int = 1,
        fit_options: dict = dict(),
        predict_options: dict = dict(),
    ) -> Result:
        self.observations.append(observation)
        if len(self.observations) < (
            lookback 
            if lookback is not None else 
            # TODO what if this is None as well??
            self.observations.maxlen
        ):
            return None
            
        [res, ] = self.predict([list(self.observations)], **predict_options)
        self.experience.append((list(self.observations), res))
        if len(self.experience) >= experience_len:
            self.fit(list(self.true_experience), **fit_options)
            self.experience.clear()        
        return res
# Out:
# env: KERAS_BACKEND=tensorflow
# 2024-11-03 05:20:33.063251: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1730611233.074333   52488 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1730611233.077625   52488 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-03 05:20:33.090146: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pandas as pd
import plotly.graph_objects
df = pd.read_csv('filtered_solar_data.csv')

predictor = PVPredictor(lookback=2_000)

fig = plotly.graph_objects.FigureWidget()
fig.add_scatter(y=[], name='truth')
fig.add_scatter(y=[], name='predicted')
display(fig)

for out_w, directsolar_wpsqm, solarangle in zip(df['pv'], df['Direct_Solar_Radiation'], df['Solar_Azimuth_Angle']):
    predicted = predictor(
        {'out_w': out_w, 'directsolar_wpsqm': directsolar_wpsqm, 'solarangle': solarangle}, 
        experience_len=100,
        fit_options=dict(epochs=16),
        predict_options=dict(verbose=0),
    )

    if predicted is not None:
        fig.data[0].y += (out_w, )
        fig.data[1].y += (predicted['out_w'].cpu().numpy() if predicted is not None else None, )
# Out:
# FigureWidget({
#     'data': [{'name': 'truth', 'type': 'scatter', 'uid': 'd84f5c62-a7d2-4e67-b9ef-09084da2c413', 'y': []},
#              {'name': 'predicted', 'type': 'scatter', 'uid': '7fbeada8-8233-4a10-9c1d-394f5b876728', 'y': []}],
#     'layout': {'template': '...'}
# })
# W0000 00:00:1730611235.618718   52488 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:tensorflow:From /tmp/ipykernel_52488/2489099940.py:22: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity with explicit device placement instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#      10 display(fig)
#      12 for out_w, directsolar_wpsqm, solarangle in zip(df['pv'], df['Direct_Solar_Radiation'], df['Solar_Azimuth_Angle']):
# ---> 13     predicted = predictor(
#      14         {'out_w': out_w, 'directsolar_wpsqm': directsolar_wpsqm, 'solarangle': solarangle},
#      15         experience_len=100,
#      16         fit_options=dict(epochs=16),
#      17         predict_options=dict(verbose=0),
#      18     )
#      20     if predicted is not None:
#      21         fig.data[0].y += (out_w, )
#
# Cell In[2], line 159, in PVPredictor.__call__(self, observation, lookback, experience_len, fit_options, predict_options)
#     151 if len(self.observations) < (
#     152     lookback
#     153     if lookback is not None else
#     154     # TODO what if this is None as well??
#     155     self.observations.maxlen
#     156 ):
#     157     return None
# --> 159 [res, ] = self.predict([list(self.observations)], **predict_options)
#     160 self.experience.append((list(self.observations), res))
#     161 if len(self.experience) >= experience_len:
#
# Cell In[2], line 123, in PVPredictor.predict(self, data_batch, **kwargs)
#     122 def predict(self, data_batch: Batch[list[Observation]], **kwargs) -> Batch[Result]:
# --> 123     output_batch = self.model.predict(
#     124         np.array([[list(obs.values()) for obs in batch] for batch in data_batch]),
#     125         **kwargs,
#     126     )
#     127     res = [{'out_w': output[0]} for output in output_batch]
#     128     return res
#
# Cell In[2], line 69, in PVPredictorModel.predict(self, inputs, **kwargs)
#      68 def predict(self, inputs, **kwargs):
# ---> 69     output = self._model.predict(
#      70         self._input_normalizer(inputs),
#      71         **kwargs,
#      72     )
#      74     denormalizer = self._invert_normalizer(
#      75         self._output_normalizer
#      76     )
#      77     return denormalizer(output)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:448, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     443 @traceback_utils.filter_traceback
#     444 def predict(
#     445     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     446 ):
#     447     # Create an iterator that yields batches of input data.
# --> 448     epoch_iterator = TFEpochIterator(
#     449         x=x,
#     450         batch_size=batch_size,
#     451         steps_per_epoch=steps,
#     452         shuffle=False,
#     453         distribute_strategy=self.distribute_strategy,
#     454         steps_per_execution=self.steps_per_execution,
#     455     )
#     457     # Container that configures and calls callbacks.
#     458     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:666, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     664 super().__init__(*args, **kwargs)
#     665 self._distribute_strategy = distribute_strategy
# --> 666 dataset = self._get_iterator()
#     667 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     668     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     669         dataset
#     670     )
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:675, in TFEpochIterator._get_iterator(self)
#     674 def _get_iterator(self):
# --> 675     return self.data_adapter.get_tf_dataset()
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:232, in ArrayDataAdapter.get_tf_dataset(self)
#     229     dataset = dataset.with_options(options)
#     230     return dataset
# --> 232 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/data/ops/dataset_ops.py:2389, in DatasetV2.flat_map(self, map_func, name)
#    2385 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2386 # dataset_ops).
#    2387 # pylint: disable=g-import-not-at-top,protected-access
#    2388 from tensorflow.python.data.ops import flat_map_op
# -> 2389 return flat_map_op._flat_map(self, map_func, name=name)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/data/ops/flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/data/ops/flat_map_op.py:33, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      30 def __init__(self, input_dataset, map_func, name=None):
#      32   self._input_dataset = input_dataset
# ---> 33   self._map_func = structured_function.StructuredFunctionWrapper(
#      34       map_func, self._transformation_name(), dataset=input_dataset)
#      35   if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#      36     raise TypeError(
#      37         "The `map_func` argument must return a `Dataset` object. Got "
#      38         f"{dataset_ops.get_type(self._map_func.output_structure)!r}.")
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/data/ops/structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1031, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1022 # Note: `nest.flatten` sorts by keys, as does `_deterministic_dict_values`.
#    1023 # Variables to help check whether mutation happens in calling the function
#    1024 # Copy the recursive list, tuple and map structure, but not base objects
#    1025 func_args_before = nest.pack_sequence_as(
#    1026     func_args,
#    1027     nest.flatten(func_args, expand_composites=True),
#    1028     expand_composites=True)
#    1029 func_kwargs_before = nest.pack_sequence_as(
#    1030     func_kwargs,
# -> 1031     nest.flatten(func_kwargs, expand_composites=True),
#    1032     expand_composites=True)
#    1034 def convert(x):
#    1035   """Converts a function output to a Tensor."""
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/util/nest.py:293, in flatten(structure, expand_composites)
#     198 @tf_export("nest.flatten")
#     199 def flatten(structure, expand_composites=False):
#     200   """Returns a flat list from a given structure.
#     201
#     202   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     291     TypeError: The nest is or contains a dict with non-sortable keys.
#     292   """
# --> 293   return nest_util.flatten(
#     294       nest_util.Modality.CORE, structure, expand_composites
#     295   )
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:712, in flatten(modality, structure, expand_composites)
#     616 """Flattens a nested structure.
#     617
#     618 - For Modality.CORE: refer to
#    (...)
#     709   TypeError: The nest is or contains a dict with non-sortable keys.
#     710 """
#     711 if modality == Modality.CORE:
# --> 712   return _tf_core_flatten(structure, expand_composites)
#     713 elif modality == Modality.DATA:
#     714   return _tf_data_flatten(structure)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:726, in _tf_core_flatten(structure, expand_composites)
#     724   return [None]
#     725 expand_composites = bool(expand_composites)
# --> 726 return _pywrap_utils.Flatten(structure, expand_composites)
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
tf.executing_eagerly()
# Out:
# True

# %%
from predict_next import PVPredictor

predictor = PVPredictor(lookback=100)


for _ in range(1000):
    predictor(
        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003,},
        experience_len=10,
        #fit_options=dict(epochs=16),
        #predict_options=dict(verbose=0),
    )
# Out:
# predict [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]] <class 'tensorflow.python.framework.ops.EagerTensor'> tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32)
# TODO rm tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32) [<tf.Tensor: shape=(1, 100, 2), dtype=float32, numpy=
# array([[[ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386]]], dtype=float32)>] [<class 'int'>]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# predict [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]] <class 'tensorflow.python.framework.ops.EagerTensor'> tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32)
# TODO rm tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32) [<tf.Tensor: shape=(1, 100, 2), dtype=float32, numpy=
# array([[[ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386]]], dtype=float32)>] [<class 'int'>]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# predict [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]] <class 'tensorflow.python.framework.ops.EagerTensor'> tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32)
# TODO rm tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32) [<tf.Tensor: shape=(1, 100, 2), dtype=float32, numpy=
# array([[[ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386]]], dtype=float32)>] [<class 'int'>]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# predict [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]] <class 'tensorflow.python.framework.ops.EagerTensor'> tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32)
# TODO rm tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32) [<tf.Tensor: shape=(1, 100, 2), dtype=float32, numpy=
# array([[[ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386]]], dtype=float32)>] [<class 'int'>]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# predict [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]] <class 'tensorflow.python.framework.ops.EagerTensor'> tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32)
# TODO rm tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32) [<tf.Tensor: shape=(1, 100, 2), dtype=float32, numpy=
# array([[[ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386]]], dtype=float32)>] [<class 'int'>]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# predict [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]] <class 'tensorflow.python.framework.ops.EagerTensor'> tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32)
# TODO rm tf.Tensor(
# [[[ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]
#   [ 0.    28.386]]], shape=(1, 100, 2), dtype=float32) [<tf.Tensor: shape=(1, 100, 2), dtype=float32, numpy=
# array([[[ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
#         [ 0.   , 28.386],
# ...
#     195         @tf.autograph.experimental.do_not_convert
#     196         def one_step_on_data(data):
#     197             """Runs a predict test step on a batch of data."""
# --> 198             return self.predict_step(data)
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py in ?(self, data)
#      93     def predict_step(self, data):
#      94         x, _, _ = data_adapter_utils.unpack_x_y_sample_weight(data)
#      95         if self._call_has_training_arg:
# ---> 96             y_pred = self(x, training=False)
#      97         else:
#      98             y_pred = self(x)
#      99         return y_pred
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     937                     "layers will not see the mask."
#     938                 )
#     939         finally:
#     940             # Destroy call context if we created it
# --> 941             self._maybe_reset_call_context()
#     942         return outputs
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/sequential.py in ?(self, inputs, training, mask)
#     211     def call(self, inputs, training=None, mask=None):
#     212         if self._functional:
# --> 213             return self._functional.call(inputs, training=training, mask=mask)
#     214
#     215         # Fallback: Just apply the layer sequence.
#     216         # This typically happens if `inputs` is a nested struct.
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py in ?(self, inputs, training, mask)
#     178             masks = tree.flatten(mask)
#     179             for x, mask in zip(inputs, masks):
#     180                 if mask is not None:
#     181                     backend.set_keras_mask(x, mask)
# --> 182         outputs = self._run_through_graph(
#     183             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184         )
#     185         return unpack_singleton(outputs)
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/function.py in ?(self, inputs, operation_fn, call_fn)
#     167                 op = operation_fn(node.operation)
#     168                 if call_fn is not None:
#     169                     outputs = call_fn(op, *args, **kwargs)
#     170                 else:
# --> 171                     outputs = op(*args, **kwargs)
#     172
#     173                 # Update tensor_dict.
#     174                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/models/functional.py in ?(*args, **kwargs)
#     580             and operation._call_has_training_arg
#     581             and training is not None
#     582         ):
#     583             kwargs["training"] = training
# --> 584         return operation(*args, **kwargs)
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     937                     "layers will not see the mask."
#     938                 )
#     939         finally:
#     940             # Destroy call context if we created it
# --> 941             self._maybe_reset_call_context()
#     942         return outputs
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/bidirectional.py in ?(self, sequences, initial_state, mask, training)
#     214         else:
#     215             forward_inputs, backward_inputs = sequences, sequences
#     216             forward_state, backward_state = None, None
#     217
# --> 218         y = self.forward_layer(
#     219             forward_inputs, initial_state=forward_state, **kwargs
#     220         )
#     221         y_rev = self.backward_layer(
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     937                     "layers will not see the mask."
#     938                 )
#     939         finally:
#     940             # Destroy call context if we created it
# --> 941             self._maybe_reset_call_context()
#     942         return outputs
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/lstm.py in ?(self, sequences, initial_state, mask, training)
#     569     def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 570         return super().call(
#     571             sequences, mask=mask, training=training, initial_state=initial_state
#     572         )
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py in ?(self, sequences, initial_state, mask, training)
#     402         self._maybe_config_dropout_masks(
#     403             self.cell, sequences[:, 0, :], initial_state
#     404         )
#     405
# --> 406         last_output, outputs, states = self.inner_loop(
#     407             sequences=sequences,
#     408             initial_state=initial_state,
#     409             mask=mask,
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/lstm.py in ?(self, sequences, initial_state, mask, training)
#     561                 "but cuDNN is not supported for this layer configuration "
#     562                 "with this backend. Pass use_cudnn='auto' to fallback "
#     563                 "to a non-cuDNN implementation."
#     564             )
# --> 565         return super().inner_loop(
#     566             sequences, initial_state, mask=mask, training=training
#     567         )
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py in ?(self, sequences, initial_state, mask, training)
#     342
#     343         if not tree.is_nested(initial_state):
#     344             initial_state = [initial_state]
#     345
# --> 346         return backend.rnn(
#     347             step,
#     348             sequences,
#     349             initial_state,
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/rnn.py in ?(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     424                     initial_states, flat_new_state
#     425                 )
#     426                 return (time + 1, output_ta_t) + tuple(new_states)
#     427
# --> 428             final_outputs = tf.while_loop(
#     429                 body=_step,
#     430                 loop_vars=(time, output_ta) + states,
#     431                 **while_loop_kwargs,
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     656                   _call_location(), decorator_utils.get_qualified_name(func),
#     657                   func.__module__, arg_name, arg_value,
#     658                   'in a future version' if date is None else
#     659                   ('after %s' % date), instructions)
# --> 660       return func(*args, **kwargs)
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#     237   ...   print(sess.run(x_out).shape)
#     238   (1000, 100)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     484
#     485       loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                               list(loop_vars))
#     487       while cond(*loop_vars):
# --> 488         loop_vars = body(*loop_vars)
#     489         if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490           packed = True
#     491           loop_vars = (loop_vars,)
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py in ?(i, lv)
# --> 479         body = lambda i, lv: (i + 1, orig_body(*lv))
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/rnn.py in ?(time, output_ta_t, *states)
#     422
#     423                 new_states = tree.pack_sequence_as(
#     424                     initial_states, flat_new_state
#     425                 )
# --> 426                 return (time + 1, output_ta_t) + tuple(new_states)
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/framework/override_binary_operator.py in ?(x, y)
#     110         # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111         #   r_binary_op_wrapper use different force_same_dtype values.
#     112         x, y = maybe_promote_tensors(x, y)
#     113         return func(x, y, name=name)
# --> 114       except (TypeError, ValueError) as e:
#     115         # Even if dispatching the op failed, the RHS may be a tensor aware
#     116         # object that can implement the operator with knowledge of itself
#     117         # and the tensor.
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/ops/tensor_math_operator_overrides.py in ?(x, y, name)
#      25 def _add_dispatch_factory(x, y, name=None):
#      26   from tensorflow.python.ops import math_ops
#      27
# ---> 28   return math_ops._add_dispatch(x, y, name=name)  # pylint: disable=protected-access
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y, name)
#    1713     y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
#    1714   if x.dtype == dtypes.string:
#    1715     return gen_math_ops.add(x, y, name=name)
#    1716   else:
# -> 1717     return gen_math_ops.add_v2(x, y, name=name)
#
# ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, y, name)
# --> 459 def add_v2(x: Annotated[Any, TV_AddV2_T], y: Annotated[Any, TV_AddV2_T], name=None) -> Annotated[Any, TV_AddV2_T]:
#     460   r"""Returns x + y element-wise.
#     461
#     462   *NOTE*: `Add` supports broadcasting. `AddN` does not. More about broadcasting
#
# KeyboardInterrupt:

# %%
import keras
keras.config.disable_traceback_filtering()

from predict_next import PVPredictor

predictor = PVPredictor(lookback=10)


for _ in range(20):
    print(
        predictor(
            {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
            experience_len=10,
            #fit_options=dict(epochs=16),
            #predict_options=dict(verbose=0),
        )
    )
# Out:
# 2024-11-03 14:05:36.708251: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1730642736.719373  285829 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1730642736.722768  285829 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-03 14:05:36.735642: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# W0000 00:00:1730642738.116597  285829 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 3.7691e-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# {'out_w': 2.0499834e-12}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# {'out_w': 2.0499834e-12}

# %%
predictor.observations
# Out:
# deque([{'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
#        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
#        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
#        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
#        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
#        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
#        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
#        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
#        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123},
#        {'out_w': 0.0, 'Drybulb_Temperature': 28.386000000000003, 'a': 123}],
#       maxlen=10)

# %%
import sklearn.preprocessing

sklearn.preprocessing.StandardScaler().fit_transform([1, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 import sklearn.preprocessing
# ----> 3 sklearn.preprocessing.StandardScaler().fit_transform([1, 2, 3])
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:878, in StandardScaler.fit(self, X, y, sample_weight)
#     876 # Reset internal state before fitting
#     877 self._reset()
# --> 878 return self.partial_fit(X, y, sample_weight)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:914, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     882 """Online computation of mean and std on X for later scaling.
#     883
#     884 All of X is processed as a single batch. This is intended for cases
#    (...)
#     911     Fitted scaler.
#     912 """
#     913 first_call = not hasattr(self, "n_samples_seen_")
# --> 914 X = self._validate_data(
#     915     X,
#     916     accept_sparse=("csr", "csc"),
#     917     dtype=FLOAT_DTYPES,
#     918     force_all_finite="allow-nan",
#     919     reset=first_call,
#     920 )
#     921 n_features = X.shape[1]
#     923 if sample_weight is not None:
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~/lab/reports/2024xxxx/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:1050, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043         else:
#    1044             msg = (
#    1045                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1046                 "Reshape your data either using array.reshape(-1, 1) if "
#    1047                 "your data has a single feature or array.reshape(1, -1) "
#    1048                 "if it contains a single sample."
#    1049             )
# -> 1050         raise ValueError(msg)
#    1052 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1053     raise ValueError(
#    1054         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1055         "Convert your data to numeric values explicitly instead."
#    1056     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1. 2. 3.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
